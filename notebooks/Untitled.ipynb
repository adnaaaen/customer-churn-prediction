# %%
import pandas as pd
import os

# %%
os.chdir("../")

# %%
from src.utils import load_dataset

# %%
df = load_dataset("cleaned/cleaned.csv")
# Out:
# 2025-01-13 23:19:45,957: INFO, on helpers, lineno=16, dataset load from /home/adnan/Documents/customer-churn-prediction/data/cleaned/cleaned.csv

# %%
df[df["churn"]  == 0]
# Out:
#         age  gender  tenure  usage_frequency  support_calls  payment_delay  \
# 135      36  Female       5                6              0              6
# 146      48    Male      49               20              1              7
# 153      24    Male      14               22              2             17
# 176      48    Male       3               30              1             10
# 187      32  Female      35                9              1             15
# ...     ...     ...     ...              ...            ...            ...
# 486509   65    Male       8               13              1             27
# 486510   55  Female      42               18              2              2
# 486511   64  Female       2                6              0             22
# 486514   54    Male      15               30              7              5
# 486515   23  Female      10                2              8              1
#
# ...

# %%
df.dtypes
# Out:
# age                    int64
# gender                object
# tenure                 int64
# usage_frequency        int64
# support_calls          int64
# payment_delay          int64
# subscription_type     object
# contract_length       object
# total_spend          float64
# last_interaction       int64
# churn                  int64
# dtype: object
