# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv("../data/cleaned/cleaned.csv")

# %%
numerical_features = df.select_dtypes("number").columns
categorical_features = df.select_dtypes("object").columns

# %%
df.head()
# Out:
#    age  gender  tenure  usage_frequency  support_calls  payment_delay  \
# 0   30  Female      39               14              5             18
# 1   65  Female      49                1             10              8
# 2   55  Female      14                4              6             18
# 3   58    Male      38               21              7              7
# 4   23    Male      32               20              5              8
#
#   subscription_type contract_length  total_spend  last_interaction  churn
# 0          Standard          Annual        932.0                17      1
# 1             Basic         Monthly        557.0                 6      1
# 2             Basic       Quarterly        185.0                 3      1
# 3          Standard         Monthly        396.0                29      1
# 4             Basic         Monthly        617.0                20      1

# %% [markdown]
# ### ***Label Encoding***

# %%
# for col in categorical_features:
#     label_encoder = LabelEncoder()
#     df[col] = label_encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#    age  gender  tenure  usage_frequency  support_calls  payment_delay  \
# 0   30  Female      39               14              5             18
# 1   65  Female      49                1             10              8
# 2   55  Female      14                4              6             18
# 3   58    Male      38               21              7              7
# 4   23    Male      32               20              5              8
#
#   subscription_type contract_length  total_spend  last_interaction  churn
# 0          Standard          Annual        932.0                17      1
# 1             Basic         Monthly        557.0                 6      1
# 2             Basic       Quarterly        185.0                 3      1
# 3          Standard         Monthly        396.0                29      1
# 4             Basic         Monthly        617.0                20      1

# %%
df["subscription_type"].value_counts()
# Out:
# subscription_type
# Standard    170630
# Premium     170099
# Basic       164477
# Name: count, dtype: int64

# %%
df["contract_length"].value_counts()
# Out:
# contract_length
# Annual       198608
# Quarterly    197364
# Monthly      109234
# Name: count, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      280273
# Female    224933
# Name: count, dtype: int64

# %%
def transform_data() -> bool:
    categorical_pipeline = Pipeline(
        steps=[("encoder", OrdinalEncoder()), ("scaler", StandardScaler())]
    )

    numerical_pipeline = Pipeline(steps=[("scaler", StandardScaler())])

    preprocessor = ColumnTransformer(
        transformers=[
            ("numerical", numerical_pipeline, numerical_features),
            ("categorical", categorical_pipeline, categorical_features),
        ]
    )

    preprocessed_df = preprocessor.fit_transform(df)
    return preprocessed_df

# %%
new_data = transform_data()

# %%
new_df = pd.DataFrame(new_data, columns=df.columns)

# %%
new_df.head()
# Out:
#         age    gender    tenure  usage_frequency  support_calls  \
# 0 -0.765883  0.443776 -0.198951         0.372314       0.532844
# 1  1.996425  1.023907 -1.707192         1.967923      -0.650423
# 2  1.207194 -1.006554 -1.359137         0.691436       0.532844
# 3  1.443963  0.385762  0.613178         1.010558      -0.768750
# 4 -1.318345  0.037683  0.497160         0.372314      -0.650423
#
#    payment_delay  subscription_type  contract_length  total_spend  \
# 0       1.271517           0.277572         0.895066    -1.116257
# 1      -0.257105          -1.000267         0.895066    -1.116257
# 2      -1.773498          -1.348769         0.895066    -1.116257
# 3      -0.913393           1.671579         0.895066     0.895851
# 4      -0.012526           0.626074         0.895066     0.895851
#
#    last_interaction     churn
# 0          1.213024 -1.126764
# 1         -1.242935  0.002781
# 2         -1.242935  1.132327
# 3          1.213024  0.002781
# 4         -1.242935  0.002781
